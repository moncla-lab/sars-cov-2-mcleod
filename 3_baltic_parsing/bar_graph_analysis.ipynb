# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Data from your builds ---
data = {
    "Titration #1 (1000_1500)": {
        "non-MN_mcleod": 423,
        "greater-MN_mcleod": 210,
        "mcleod_greater-MN": 118,
        "mcleod_non-MN": 58
    },
    "Titration #2 (1500_1500)": {
        "non-MN_mcleod": 291,
        "greater-MN_mcleod": 319,
        "mcleod_greater-MN": 144,
        "mcleod_non-MN": 86
    }
}

# --- Extract keys (transitions) and values ---
transitions = list(data["Titration #1 (1000_1500)"].keys())
build1_counts = [data["Titration #1 (1000_1500)"][t] for t in transitions]
build2_counts = [data["Titration #2 (1500_1500)"][t] for t in transitions]

# --- Set up positions ---
x = np.arange(len(transitions))  # label locations
width = 0.35  # width of the bars

# --- Plot ---
fig, ax = plt.subplots(figsize=(8,6))
bars1 = ax.bar(x - width/2, build1_counts, width, label="Titration #1 (1000_1500)", color="steelblue")
bars2 = ax.bar(x + width/2, build2_counts, width, label="Titration #2 (1500_1500)", color="orange")

# --- Labels & Formatting ---
ax.set_ylabel("Count of Strains")
ax.set_xlabel("Transition")
ax.set_title("Transitions based on Mcleod Status")
ax.set_xticks(x)
ax.set_xticklabels([t.replace("_", " → ") for t in transitions], rotation=20)
ax.legend()

# Add value labels above bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontweight='bold')

add_labels(bars1)
add_labels(bars2)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Data from your builds ---
data = {
    "Version 1 (2000_1500)": {
        "greater-MN_mcleod": 329,
        "mcleod_greater-MN": 108,
        "non-MN_mcleod": 387,
        "mcleod_non-MN": 41
    },
    "Version 2 (2500_1500)": {
        "greater-MN_mcleod": 316,
        "mcleod_greater-MN": 115,
        "non-MN_mcleod": 399,
        "mcleod_non-MN": 55
    },
    "Version 3 (3000_1500)": {
        "greater-MN_mcleod": 336,
        "mcleod_greater-MN": 84,
        "non-MN_mcleod": 422,
        "mcleod_non-MN": 48
    }
}

# --- Extract transitions and values ---
transitions = list(next(iter(data.values())).keys())
versions = list(data.keys())
counts = [[data[v][t] for t in transitions] for v in versions]

# --- Plot setup ---
x = np.arange(len(transitions))  # transition positions
width = 0.25  # width of each bar
colors = ["steelblue", "orange", "seagreen"]

fig, ax = plt.subplots(figsize=(10,6))

bars = []
for i, version in enumerate(versions):
    bar = ax.bar(x + i*width - width, counts[i], width, label=version, color=colors[i])
    bars.append(bar)

# --- Labels & Formatting ---
ax.set_ylabel("Count of Strains")
ax.set_xlabel("Transition")
ax.set_title("Transitions into and out of McLeod County")
ax.set_xticks(x)
ax.set_xticklabels([t.replace("_", " → ") for t in transitions], rotation=20)
ax.legend()

# Add value labels above bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontweight='bold')

for barset in bars:
    add_labels(barset)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Data from all builds/versions ---
data = {
    "Titration #1 (1000_1500)": {
        "non-MN_mcleod": 423,
        "greater-MN_mcleod": 210,
        "mcleod_greater-MN": 118,
        "mcleod_non-MN": 58
    },
    "Titration #2 (1500_1500)": {
        "non-MN_mcleod": 291,
        "greater-MN_mcleod": 319,
        "mcleod_greater-MN": 144,
        "mcleod_non-MN": 86
    },
    "Titration #3 (2000_1500)": {
        "greater-MN_mcleod": 329,
        "mcleod_greater-MN": 108,
        "non-MN_mcleod": 387,
        "mcleod_non-MN": 41
    },
    "Titration #4 (2500_1500)": {
        "greater-MN_mcleod": 316,
        "mcleod_greater-MN": 115,
        "non-MN_mcleod": 399,
        "mcleod_non-MN": 55
    },
    "Titration #5 (3000_1500)": {
        "greater-MN_mcleod": 336,
        "mcleod_greater-MN": 84,
        "non-MN_mcleod": 422,
        "mcleod_non-MN": 48
    }
}

# --- Extract transitions and values ---
transitions = list(next(iter(data.values())).keys())
builds = list(data.keys())
counts = [[data[b][t] for t in transitions] for b in builds]

# --- Plot setup ---
x = np.arange(len(transitions))  # transition positions
width = 0.15  # smaller width since more bars
colors = ["steelblue", "orange", "seagreen", "mediumpurple", "tomato"]

fig, ax = plt.subplots(figsize=(12,6))

bars = []
for i, build in enumerate(builds):
    bar = ax.bar(x + (i - len(builds)/2)*width + width/2, counts[i], 
                 width, label=build, color=colors[i % len(colors)])
    bars.append(bar)

# --- Labels & Formatting ---
ax.set_ylabel("Count of Strains")
ax.set_xlabel("Transition")
ax.set_title("Transitions into and out of McLeod County")
ax.set_xticks(x)
ax.set_xticklabels([t.replace("_", " → ") for t in transitions], rotation=20)
ax.legend()

# Add value labels above bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontweight='bold')

for barset in bars:
    add_labels(barset)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Versions (x-axis labels)
versions = ["titration3_2000_1500", "titration4_2500_1500", "titration5_3000_1500"]

# Cluster mappings (manually linked across versions)
cluster_471_502_325 = [50, 50, 45]  # cluster #471 -> #502 -> #325
cluster_556_344_297 = [45, 45, 28]  # cluster #556 -> #344 -> #297

# Plot
plt.figure(figsize=(8, 5))

plt.plot(versions, cluster_471_502_325, marker="o", label="Cluster #471/#502/#325")
plt.plot(versions, cluster_556_344_297, marker="o", label="Cluster #556/#344/#297")

# Labels
plt.xlabel("Versions")
plt.ylabel("Cluster Size (# strains)")
plt.title("Cluster stability across increasing strain numbers")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data
data = {
    'Transition': [
        'non-MN_mcleod',
        'TC_county_mcleod',
        'greater-MN_mcleod',
        'mcleod_non-MN',
        'mcleod_TC_county',
        'mcleod_greater-MN'
    ],
    'Count': [456, 84, 119, 48, 72, 88]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Make the bar plot
plt.figure(figsize=(8, 5))
plt.bar(df['Transition'], df['Count'], color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transition', fontsize=12)
plt.ylabel('Number of Strains', fontsize=12)
plt.title('Strain Transitions TC Titration #1', fontsize=14)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data
data = {
    'Transition': [
        'non-MN_mcleod',
        'greater-MN_mcleod',
        'mcleod_non-MN',
        'mcleod_greater-MN'
    ],
    'Count': [387, 329, 41, 108]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Make the bar plot
plt.figure(figsize=(8, 5))
plt.bar(df['Transition'], df['Count'], color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transition', fontsize=12)
plt.ylabel('Number of Strains', fontsize=12)
plt.title('Titration 3: Transitions', fontsize=14)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data
data = {
    'Transition': [
        'non-MN_mcleod',
        'greater-MN_mcleod',
        'mcleod_non-MN',
        'mcleod_greater-MN'
    ],
    'Count': [274, 155, 161, 101]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Make the bar plot
plt.figure(figsize=(8, 5))
plt.bar(df['Transition'], df['Count'], color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transition', fontsize=12)
plt.ylabel('Number of Strains', fontsize=12)
plt.title('Pre-Titration Transitions', fontsize=14)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data
data = {
    'Transition': [
        'non-MN_mcleod',
        'TC_county_mcleod',
        'greater-MN_mcleod',
        'mcleod_non-MN',
        'mcleod_TC_county',
        'mcleod_greater-MN'
    ],
    'Count': [385, 163, 147, 49, 92, 74]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Make the bar plot
plt.figure(figsize=(8, 5))
plt.bar(df['Transition'], df['Count'], color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transition', fontsize=12)
plt.ylabel('Number of Strains', fontsize=12)
plt.title('Strain Transitions TC Titration #2', fontsize=14)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Data ---
data = {
    "TC Titration #1": {
        "non-MN_mcleod": 456,
        "TC_county_mcleod": 84,
        "greater-MN_mcleod": 119,
        "mcleod_non-MN": 48,
        "mcleod_TC_county": 72,
        "mcleod_greater-MN": 88
    },
    "TC Titration #2": {
        "non-MN_mcleod": 385,
        "TC_county_mcleod": 163,
        "greater-MN_mcleod": 147,
        "mcleod_non-MN": 49,
        "mcleod_TC_county": 92,
        "mcleod_greater-MN": 74
    }
}

# --- Extract transitions and values ---
transitions = list(next(iter(data.values())).keys())
builds = list(data.keys())
counts = [[data[b][t] for t in transitions] for b in builds]

# --- Plot setup ---
x = np.arange(len(transitions))  # transition positions
width = 0.45  # smaller width since more bars
colors = ["steelblue", "orange"]

fig, ax = plt.subplots(figsize=(12,6))

bars = []
for i, build in enumerate(builds):
    bar = ax.bar(x + (i - len(builds)/2)*width + width/2, counts[i], 
                 width, label=build, color=colors[i % len(colors)])
    bars.append(bar)

# --- Labels & Formatting ---
ax.set_ylabel("Count of Strains")
ax.set_xlabel("Transition")
ax.set_title("Transitions into and out of McLeod County including TC_status")
ax.set_xticks(x)
ax.set_xticklabels([t.replace("_", " → ") for t in transitions], rotation=20)
ax.legend()

# Add value labels above bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontweight='bold')

for barset in bars:
    add_labels(barset)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data
data = {
    'Transition': [
        'non-MN_mcleod',
        'TC_county_mcleod',
        'greater-MN_mcleod',
        'mcleod_non-MN',
        'mcleod_TC_county',
        'mcleod_greater-MN'
    ],
    'Count': [386, 207, 114, 43, 90, 65]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Make the bar plot
plt.figure(figsize=(8, 5))
plt.bar(df['Transition'], df['Count'], color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transition', fontsize=12)
plt.ylabel('Number of Strains', fontsize=12)
plt.title('Strain Transitions TC Titration #3', fontsize=14)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Data ---
data = {
    "TC Titration #1": {
        "non-MN_mcleod": 456,
        "TC_county_mcleod": 84,
        "greater-MN_mcleod": 119,
        "mcleod_non-MN": 48,
        "mcleod_TC_county": 72,
        "mcleod_greater-MN": 88
    },
    "TC Titration #2": {
        "non-MN_mcleod": 385,
        "TC_county_mcleod": 163,
        "greater-MN_mcleod": 147,
        "mcleod_non-MN": 49,
        "mcleod_TC_county": 92,
        "mcleod_greater-MN": 74
    },
    "TC Titration #3": {
        "non-MN_mcleod": 386,
        "TC_county_mcleod": 207,
        "greater-MN_mcleod": 114,
        "mcleod_non-MN": 43,
        "mcleod_TC_county": 90,
        "mcleod_greater-MN": 65
    }
}

# --- Extract transitions and values ---
transitions = list(next(iter(data.values())).keys())
builds = list(data.keys())
counts = [[data[b][t] for t in transitions] for b in builds]

# --- Plot setup ---
x = np.arange(len(transitions))  # transition positions
width = 0.3  # smaller width since more bars
colors = ["steelblue", "orange", "seagreen"]

fig, ax = plt.subplots(figsize=(12,6))

bars = []
for i, build in enumerate(builds):
    bar = ax.bar(x + (i - len(builds)/2)*width + width/2, counts[i], 
                 width, label=build, color=colors[i % len(colors)])
    bars.append(bar)

# --- Labels & Formatting ---
ax.set_ylabel("Count of Strains")
ax.set_xlabel("Transition")
ax.set_title("Transitions into and out of McLeod County including TC_status")
ax.set_xticks(x)
ax.set_xticklabels([t.replace("_", " → ") for t in transitions], rotation=20)
ax.legend()

# Add value labels above bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontweight='bold')

for barset in bars:
    add_labels(barset)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data
data = {
    'Transition': [
        'non-MN_mcleod',
        'TC_county_mcleod',
        'greater-MN_mcleod',
        'mcleod_non-MN',
        'mcleod_TC_county',
        'mcleod_greater-MN'
    ],
    'Count': [228, 249, 191, 66, 114, 131]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Make the bar plot
plt.figure(figsize=(8, 5))
plt.bar(df['Transition'], df['Count'], color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transition', fontsize=12)
plt.ylabel('Number of Strains', fontsize=12)
plt.title('Strain Transitions TC Titration #4', fontsize=14)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Data ---
data = {
    "TC Titration #1": {
        "non-MN_mcleod": 456,
        "TC_county_mcleod": 84,
        "greater-MN_mcleod": 119,
        "mcleod_non-MN": 48,
        "mcleod_TC_county": 72,
        "mcleod_greater-MN": 88
    },
    "TC Titration #2": {
        "non-MN_mcleod": 385,
        "TC_county_mcleod": 163,
        "greater-MN_mcleod": 147,
        "mcleod_non-MN": 49,
        "mcleod_TC_county": 92,
        "mcleod_greater-MN": 74
    },
    "TC Titration #3": {
        "non-MN_mcleod": 386,
        "TC_county_mcleod": 207,
        "greater-MN_mcleod": 114,
        "mcleod_non-MN": 43,
        "mcleod_TC_county": 90,
        "mcleod_greater-MN": 65
    },
    "TC Titration #4": {
        "non-MN_mcleod": 228,
        "TC_county_mcleod": 249,
        "greater-MN_mcleod": 191,
        "mcleod_non-MN": 66,
        "mcleod_TC_county": 114,
        "mcleod_greater-MN": 131
    }
}

# --- Extract transitions and values ---
transitions = list(next(iter(data.values())).keys())
builds = list(data.keys())
counts = [[data[b][t] for t in transitions] for b in builds]

# --- Plot setup ---
x = np.arange(len(transitions))  # transition positions
width = 0.2  # smaller width since more bars
colors = ["steelblue", "orange", "seagreen", "red"]

fig, ax = plt.subplots(figsize=(12,6))

bars = []
for i, build in enumerate(builds):
    bar = ax.bar(x + (i - len(builds)/2)*width + width/2, counts[i], 
                 width, label=build, color=colors[i % len(colors)])
    bars.append(bar)

# --- Labels & Formatting ---
ax.set_ylabel("Count of Strains")
ax.set_xlabel("Transition")
ax.set_title("Transitions into and out of McLeod County including TC_status")
ax.set_xticks(x)
ax.set_xticklabels([t.replace("_", " → ") for t in transitions], rotation=20)
ax.legend()

# Add value labels above bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontweight='bold')

for barset in bars:
    add_labels(barset)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data
data = {
    'Transition': [
        'non-MN_mcleod',
        'TC_county_mcleod',
        'greater-MN_mcleod',
        'mcleod_non-MN',
        'mcleod_TC_county',
        'mcleod_greater-MN'
    ],
    'Count': [129, 6, 159, 24, 18, 56]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Make the bar plot
plt.figure(figsize=(8, 5))
plt.bar(df['Transition'], df['Count'], color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transition', fontsize=12)
plt.ylabel('Number of Strains', fontsize=12)
plt.title('Strain Transitions Omicron Pre-Clean', fontsize=14)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data
data = {
    'Transition': [
        'non-MN_mcleod',
        'TC_county_mcleod',
        'greater-MN_mcleod',
        'mcleod_non-MN',
        'mcleod_TC_county',
        'mcleod_greater-MN'
    ],
    'Count': [291, 9, 113, 22, 20, 61]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Make the bar plot
plt.figure(figsize=(8, 5))
plt.bar(df['Transition'], df['Count'], color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transition', fontsize=12)
plt.ylabel('Number of Strains', fontsize=12)
plt.title('Strain Transitions Omicron Post-Clean Titration #1', fontsize=14)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data
data = {
    'Transition': [
        'nonMN_mcleod',
        'TCcounty_mcleod',
        'greaterMN_mcleod',
        'mcleod_nonMN',
        'mcleod_TCcounty',
        'mcleod_greaterMN'
    ],
    'Count': [229, 42, 200, 14, 11, 48]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Make the bar plot
plt.figure(figsize=(8, 5))
plt.bar(df['Transition'], df['Count'], color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transition', fontsize=12)
plt.ylabel('Number of Strains', fontsize=12)
plt.title('Strain Transitions Omicron Post-Clean Titration #2', fontsize=14)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data
data = {
    'Transition': [
        'nonMN_mcleod',
        'TCcounty_mcleod',
        'greaterMN_mcleod',
        'mcleod_nonMN',
        'mcleod_TCcounty',
        'mcleod_greaterMN'
    ],
    'Count': [209, 95, 166, 13, 14, 51]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Make the bar plot
plt.figure(figsize=(8, 5))
plt.bar(df['Transition'], df['Count'], color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transition', fontsize=12)
plt.ylabel('Number of Strains', fontsize=12)
plt.title('Strain Transitions Omicron Post-Clean Titration #3', fontsize=14)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Data ---
data = {
    "Omicron Titration #1 500_1K_1K": {
        "nonMN_mcleod": 291,
        "TCcounty_mcleod": 9,
        "greaterMN_mcleod": 113,
        "mcleod_nonMN": 22,
        "mcleod_TCcounty": 20,
        "mcleod_greaterMN": 61
    },
    "Omicron Titration #2 1500_2K_2K": {
        "nonMN_mcleod": 229,
        "TCcounty_mcleod": 42,
        "greaterMN_mcleod": 200,
        "mcleod_nonMN": 14,
        "mcleod_TCcounty": 11,
        "mcleod_greaterMN": 48
    },
    "Omicron Titration #3 2K_2K_2K": {
        "nonMN_mcleod": 209,
        "TCcounty_mcleod": 95,
        "greaterMN_mcleod": 166,
        "mcleod_nonMN": 13,
        "mcleod_TCcounty": 14,
        "mcleod_greaterMN": 51
    }
}

# --- Extract transitions and values ---
transitions = list(next(iter(data.values())).keys())
builds = list(data.keys())
counts = [[data[b][t] for t in transitions] for b in builds]

# --- Plot setup ---
x = np.arange(len(transitions))  # transition positions
width = 0.2  # smaller width since more bars
colors = ["steelblue", "orange", "seagreen", "red"]

fig, ax = plt.subplots(figsize=(12,6))

bars = []
for i, build in enumerate(builds):
    bar = ax.bar(x + (i - len(builds)/2)*width + width/2, counts[i], 
                 width, label=build, color=colors[i % len(colors)])
    bars.append(bar)

# --- Labels & Formatting ---
ax.set_ylabel("Count of Strains")
ax.set_xlabel("Transition")
ax.set_title("Omicron Transitions into and out of McLeod County including TC_status")
ax.set_xticks(x)
ax.set_xticklabels([t.replace("_", " → ") for t in transitions], rotation=20)
ax.legend()

# Add value labels above bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontweight='bold')

for barset in bars:
    add_labels(barset)

plt.tight_layout()
plt.show()
